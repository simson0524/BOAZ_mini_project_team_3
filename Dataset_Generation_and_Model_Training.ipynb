# %% [markdown]
# # 목차
#
# 1. 데이터셋 구축
#   a. 삼성전자 주가 데이터
#   b. 보조지표
#   c. 투자자별 매매동향
#   d. 뉴스기사 감성분석
# 2. 시각화
# 3. 모델 훈련
# 4. 성능 비교

# %% [markdown]
# # 데이터셋 구축

# %% [markdown]
# ## 1. 삼성전자 주가 데이터

# %%
# !pip install finance-datareader
# !pip install ta
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.93-py3-none-any.whl.metadata (466 bytes)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.1.4)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (2.32.3)
# Collecting requests-file (from finance-datareader)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.9.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from finance-datareader) (4.66.5)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->finance-datareader) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->finance-datareader) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19.2->finance-datareader) (1.16.0)
# Downloading finance_datareader-0.9.93-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.0/89.0 kB 9.5 MB/s eta 0:00:00
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.93 requests-file-2.1.0
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ta) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ta) (2.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->ta) (1.16.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=60f2327ffaf33442e202043115dc267d36cbae8e03e6f44ae1d239c6406750d3
#   Stored in directory: /root/.cache/pip/wheels/5f/67/4f/8a9f252836e053e532c6587a3230bc72a4deb16b03a829610b
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0

# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr
import ta
import tensorflow as tf

# 삼성전자 주가 데이터 불러오기
df = fdr.DataReader('005930','2014-10-01', '2024-08-28')

# %%
# 변동성
df['Volatility'] = df['Close'].rolling(window=20).std()

# CHANGE 변수 삭제
df = df.drop('Change', axis=1)

# %% [markdown]
# ## 2. 보조지표

# %% [markdown]
# ### 1. 볼린저밴드
#
# **사용하는 기술 지표: %B, 밴드폭**
# - %B: 볼린저 밴드 상에서 주가가 어느 위치에 있는지를 나타낸 지표
# - 밴드폭: 볼린저밴드의 폭

# %%
# 2번째 데이터셋 정의
df2 = df.copy().drop(columns=['Open','High','Low','Close','Volume','Volatility'])

# 볼린저밴드
bollinger_band = ta.volatility.BollingerBands(close=df['Close'], window=20, fillna=False)

df2['PB'] = bollinger_band.bollinger_pband()        # %B
df2['BandWidth'] = bollinger_band.bollinger_wband() # 밴드폭

# %% [markdown]
# ### 2. DMI, ADX
#
# 주가가 어떤 방향의 추세로 움직이고 있는지를 판단하고 그 추세의 강도를 측정하기 위해 사용되는 지표
# **사용하는 기술 지표: +DI, -DI, ADX**
# - +DI: 주가의 상승 강도
# - -DI: 주가의 하락 강도
# - ADX: 주가의 변동 추세의 강도
#
# #### 계산식
# - +DM: (당일 고가>전일 고가)이면서 (고가의 변동폭>저가의 변동폭)일 경우, (당일 고가-전일 고가)의 절댓값, 이외에는 0
# - -DM: (당일 저가<전일 저가)이면서 (고가의 변동폭<저가의 변동폭)일 경우, (당일 저가-전일 저가)의 절댓값, 이외에는 0

# %%
# pdiff = 당일 고가-전일 고가, mdiff = 당일 저가-전일 저가
high_diff, low_diff = df['High'].diff(1), df['Low'].diff(1)

plus_dm = pd.Series(np.where((high_diff > 0) & (high_diff > -low_diff), high_diff, 0), index=df.index)   # +DM
minus_dm = pd.Series(np.where((-low_diff > 0) & (-low_diff > high_diff), -low_diff, 0), index=df.index)   # -DM

# %% [markdown]
# - TR = max{(당일 고가-당일 저가), (당일 고가-전일 종가)의 절댓값, (당일 저가-전일 종가)의 절댓값}

# %%
# 최댓값을 비교하기 위해 각각의 값을 계산하여 입력하기 위한 데이터프레임 정의
tr_df = pd.DataFrame()

# 각 조건에 해당하는 값을 계산하여 입력
tr_df['Condition 1'] = df['High'] - df['Low']
tr_df['Condition 2'] = (df['High'] - df['Close'].shift(-1)).abs()
tr_df['Condition 3'] = (df['Low'] - df['Close'].shift(-1)).abs()

# 각 행으로부터 최댓값 산출하여 TR을 series로 반환
tr = tr_df.max(axis = 1)

# %% [markdown]
# ![dmi.PNG](data:image/png;base64,...)

# %%
# +DM_sum, -DM_sum, TR_sum을 계산하는 함수 정의
def sum_index(df,series):
    # 빈 시리즈 정의
    sum = pd.Series(np.nan, index=df.index)
    # 14일 동안의 DM 또는 TR 합을 계산하여 초항으로 입력
    sum.iloc[13] = series[0:14].sum()
    for i in range(14,len(df)):
        # 위의 계산식에 따라 DM_sum 또는 TR_sum을 계산하여 입력
        sum.iloc[i] = sum.iloc[i-1] - sum.iloc[i-1]/14 + series.iloc[i]
    return sum

# +DM_sum, -DM_sum, TR_sum
plus_dm_sum, minus_dm_sum, tr_sum = sum_index(df,plus_dm), sum_index(df,minus_dm), sum_index(df,tr)

# %% [markdown]
# - +DI = +DMN/TRN*100
# - -DI = -DMN/TRN*100

# %%
# +DI, -DI를 데이터프레임에 추가
df2['PDI'], df2['MDI'] = plus_dm_sum/tr_sum*100, minus_dm_sum/tr_sum*100

# %% [markdown]
# ![dx.PNG](data:image/png;base64,...)

# %%
# 위의 계산식에 따라 DX 계산
dx = ((df2['PDI']-df2['MDI']).abs()) / (df2['PDI']+df2['MDI']) * 100

# %% [markdown]
# ![adx.PNG](data:image/png;base64,...)

# %%
# ADX를 입력하기 위한 빈 series 선언
adx = pd.Series(np.nan, index=df.index)

# 14일 동안의 DX의 평균을 계산하여 ADX의 초항으로 입력
adx.iloc[26] = dx[13:27].mean()

# 위의 계산식에 따라 ADX 계산
for i in range(27,len(df2)):
    adx.iloc[i] = (adx.iloc[i-1]*13 + dx.iloc[i])/14

# ADX를 데이터프레임에 추가
df2['ADX'] = adx

# %% [markdown]
# ### 3. WMA (이동평균선)
#
# - WMA_short: 단기 이동평균선 (5일)
# - WMA_long: 장기 이동평균선 (20일)

# %%
df2['WMA_short'] = ta.trend.WMAIndicator(close=df['Close'], window=5, fillna=False).wma()
df2['WMA_long'] = ta.trend.WMAIndicator(close=df['Close'], window=20, fillna=False).wma()

# %% [markdown]
# ### 4. MACD
#
# - MACD: 주가 흐름의 추세를 확인하고 추세의 강도와 지속성을 파악하는데 활용되는 지표
# - MACD_sig: MACD의 지수이동평균 (9일)

# %%
df2['MACD'] = ta.trend.macd(close=df['Close'], window_slow=26, window_fast=12, fillna=False)
df2['MACD_sig'] = ta.trend.macd_signal(close=df['Close'], window_slow=26, window_fast=12, window_sign=9, fillna=False)

# %% [markdown]
# ### 5. RSI
#
# - RSI: 주가의 평균 상승폭과 하락폭을 비교하여 가격의 상승 압력과 하락 압력 간 상대적인 강도를 나타내는 기술적 지표
# - RSI_sig: RSI의 단순이동평균(9일)

# %%
df2['RSI'] = ta.momentum.rsi(close=df['Close'], window=14, fillna=False)
df2['RSI_sig'] = df2['RSI'].rolling(9).mean()

# %% [markdown]
# ### 6. Stochastic Fast
#
# 일정 기간 동안 최고가와 최저가의 범위 중 현재 가격의 위치를 백분율로 나타내는 지표
# - %K: 최고가와 최저가의 범위 중 현재 가격의 위치를 백분율로 나타낸 값
# - %D: %K의 이동평균

# %%
df2['%K'] = ta.momentum.stoch(high=df['High'], low=df['Low'], close=df['Close'], window=14, smooth_window=3, fillna=False)
df2['%D'] = ta.momentum.stoch_signal(high=df['High'], low=df['Low'], close=df['Close'], window=14, smooth_window=3, fillna=False)

# %%
# 2015년 1월 2일부터 시작하도록 데이터프레임 자르기
df = df[62:]

# 데이터 확인
df.tail()
# Out:
#              Open   High    Low  Close    Volume   Volatility
# Date
# 2024-08-22  78700  78900  77800  78300   8149101  3478.898797
# 2024-08-23  77700  78400  77500  77700   9420306  3432.119953
# 2024-08-26  78100  78200  76000  76100  15655938  3374.591593
# 2024-08-27  75700  76500  75600  75800  11130145  3286.699672
# 2024-08-28  75800  76400  75400  76400   9671798  3175.809056

# %%
# 2015년 1월 2일부터 시작하도록 데이터프레임 자르기
df2 = df2[62:]

# 데이터 확인
df2.tail()
# Out:
#                   PB  BandWidth        PDI        MDI        ADX  \
# Date
# 2024-08-22  0.523593  17.393235  23.690890  26.885275  17.296170
# 2024-08-23  0.489164  17.189115  22.105095  25.958748  16.633428
# 2024-08-26  0.385609  16.953263  20.558670  28.515095  16.603411
# 2024-08-27  0.380208  16.569360  19.993801  28.952769  16.724851
# 2024-08-28  0.443061  16.058081  19.357385  28.667796  16.914970
#
#                WMA_short      WMA_long         MACD     MACD_sig        RSI  \
# Date
# 2024-08-22  78546.666667  77393.809524 -1000.619600 -1378.437514  48.042565
# 2024-08-23  78180.000000  77367.142857  -946.960787 -1292.142169  46.517586
# 2024-08-26  77446.666667  77200.952381 -1021.764158 -1238.066567  42.631423
# 2024-08-27  76760.000000  77029.047619 -1092.658375 -1208.984928  41.924203
# 2024-08-28  76480.000000  76940.000000 -1087.887083 -1184.765359  43.927696
#
#               RSI_sig         %K         %D
# Date
# 2024-08-22  45.810153  72.321429  59.327269
# 2024-08-23  46.705418  75.000000  66.088275
# 2024-08-26  46.931899  48.101266  65.140898
# 2024-08-27  46.900053  42.857143  55.319470
# 2024-08-28  46.763210  50.649351  47.202586

# %% [markdown]
# ## 3. 투자자별 매매동향

# %%
# 3번째 데이터셋 정의
df3 = pd.read_csv('/content/sample_data/투자자별 매매동향(삼성전자).csv')

# 과거부터 현재 순서로 정렬해주기
df3 = df3.iloc[::-1].reset_index(drop=True)

# '기관 순매매량', '외국인 순매매량', '외국인 보유주수', '외국인 보유율' 열만 가져오기
df3 = pd.concat([df3.iloc[:len(df3)-1,0],df3.iloc[:len(df3)-1,5:]],axis=1)
df3.columns = ['날짜','기관 순매매량', '외국인 순매매량', '외국인 보유주수', '외국인 보유율']

# %%
# 2015년 1월 2일의 인덱스 확인
df3[df3['날짜'] == '2015.01.02']
# Out:
#               날짜  기관 순매매량 외국인 순매매량    외국인 보유주수 외국인 보유율
# 2482  2015.01.02  -20,583   21,328  76,336,351  51.82%

# %%
# 2015년 1월 2일부터 시작하도록 데이터프레임 자르기
df3 = df3[2482:].drop(columns=['날짜'])

# 날짜 인덱스 가져오기
df3.index = fdr.DataReader('005930','2015-01-02', '2024-08-28').index

# %%
# 각 셀의 데이터 타입을 숫자로 변환
df3['기관 순매매량'] = df3['기관 순매매량'].apply(lambda x: int(x.replace(",", "")))
df3['외국인 순매매량'] = df3['외국인 순매매량'].apply(lambda x: int(x.replace(",", "")))
df3['외국인 보유주수'] = df3['외국인 보유주수'].apply(lambda x: int(x.replace(",", "")))
df3['외국인 보유율'] = df3['외국인 보유율'].str.rstrip('%').astype(float) / 100.0

# %%
# 데이터 확인
df3.tail()
# Out:
#             기관 순매매량  외국인 순매매량    외국인 보유주수  외국인 보유율
# Date
# 2024-08-22  -452139    310180  3358830711   0.5626
# 2024-08-23   748590  -1392121  3357636890   0.5624
# 2024-08-26   584334  -3737763  3354085777   0.5618
# 2024-08-27   304677  -1446782  3352910295   0.5616
# 2024-08-28   533263  -1470392  3351439903   0.5614

# %% [markdown]
# ## 4. 뉴스기사 감성분석

# %%
# 4번째 데이터셋 정의
df4 = pd.read_csv('/content/sample_data/new_sentiment_data.csv').drop(columns=['adjusted_date'])

# 날짜 인덱스 가져오기
df4.index = fdr.DataReader('005930','2015-01-02', '2024-08-28').index

# %%
# 데이터 확인
df4.tail()
# Out:
#              neutral  positive  negative
# Date
# 2024-08-22  0.250000  0.750000  0.000000
# 2024-08-23  0.000000  0.833333  0.166667
# 2024-08-26  0.000000  0.833333  0.166667
# 2024-08-27  0.375000  0.500000  0.125000
# 2024-08-28  0.166667  0.333333  0.500000

# %%
# 데이터로 사용할것들 'df'로 concat하기
# data_frame_0 는 notion의 실험번호 순서

data_frames_1 = [df]
data_frames_2 = [df, df2]
data_frames_3 = [df, df3]
data_frames_4 = [df, df4]
data_frames_5 = [df, df2, df3]
data_frames_6 = [df, df3, df4]
data_frames_7 = [df, df2, df4]
data_frames_8 = [df, df2, df3, df4]

# 현재 사용하고자 하는 조합
df = pd.concat(data_frames_6, axis=1)

# %% [markdown]
# # 2. 시각화

# %%
def data_scaler(data):
  from sklearn.preprocessing import MinMaxScaler
  scaler = MinMaxScaler()

  scale_cols = list(data.columns)
  scaled = scaler.fit_transform(data[scale_cols])

  scaled_df = pd.DataFrame(scaled, columns=scale_cols, index=data.index)

  return scaled_df, scaler

# %%
from sklearn.model_selection import train_test_split
scaled_df, scaler = data_scaler(df)
x_train, x_test, y_train, y_test = train_test_split(scaled_df.drop(columns=["Close"]), scaled_df['Close'], test_size=0.2, random_state=42, shuffle=False)

# %%
scaled_df.shape
# Out:
# (2377, 13)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 상관관계 계산
correlation_matrix = scaled_df.corr()

plt.figure(figsize=(16, 12))

# 히트맵 시각화
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50808 (\N{HANGUL SYLLABLE OE}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44288 (\N{HANGUL SYLLABLE GWAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50808 (\N{HANGUL SYLLABLE OE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48372 (\N{HANGUL SYLLABLE BO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50984 (\N{HANGUL SYLLABLE YUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 시각화
plt.figure(figsize=(14, 7))

# 주가와 변동성의 시계열 그래프를 그립니다.
plt.subplot(2, 1, 1)
plt.plot(df.index, df['Close'], label='Close Price', color='blue')
plt.title('Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.subplot(2, 1, 2)
plt.plot(df.index, df['Volatility'], label='Volatility', color='red')
plt.title('Volatility Over Time')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. 모델 훈련

# %%
def windowed_dataset(series, window_size, batch_size, shuffle):
  series = tf.expand_dims(series, axis=-1)
  ds = tf.data.Dataset.from_tensor_slices(series)
  ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
  ds = ds.flat_map(lambda w: w.batch(window_size + 1))
  if shuffle:
    ds = ds.shuffle(1000)
  ds = ds.map(lambda w: (w[:-1], w[-1]))
  return ds.batch(batch_size).prefetch(1)

# %%
# 모델에 들어갈 변수값들
WINDOW_SIZE = 20
BATCH_SIZE = 32

# %%
def train_model(data):
  # ====================== STEP 1. train, test 데이터 정의 ======================
  global WINDOW_SIZE, BATCH_SIZE

  train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, True)
  test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

  # ============================= STEP 2. 모델 정의 =============================
  from tensorflow.keras.models import Sequential
  from tensorflow.keras.layers import Dense, LSTM, Conv1D ,Dropout, Lambda,Bidirectional, BatchNormalization
  from tensorflow.keras.losses import Huber
  from tensorflow.keras.optimizers import Adam
  from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


  model = Sequential([
      # Conv1D 레이어
      Conv1D(filters=64, kernel_size=5,
            padding="causal",
            activation="relu",
            input_shape=[WINDOW_SIZE, 1]),

      # 양방향 LSTM 레이어
      Bidirectional(LSTM(64, activation='tanh', return_sequences=False)),

      # Dropout 레이어
      Dropout(0.1),

      # Dense 레이어 (뉴런 수 증가, 배치 정규화 추가)
      Dense(25, activation='relu', name = "..."),

      # 출력 레이어
      Dense(1),
  ])

  # ============================= STEP 3. 모델 훈련 설정 =============================
  import os
  loss = Huber()
  optimizer = Adam(0.005)

  model.compile(loss=Huber(), optimizer = optimizer, metrics = ['mse'])

  # earlystopping
  earlystopping = EarlyStopping(monitor = 'val_loss', patience = 10)

  # val_loss 기준 체크포인터도 생성
  filename = os.path.join('tmp', 'checkpointer.weights.h5')
  checkpoint = ModelCheckpoint(filename,
                              save_weights_only = True,
                              save_best_only=True,
                              monitor='val_loss',
                              verbose=1)

  # ============================= STEP 4. 모델 학습 =============================
  # model fitting
  print('model1 training.....')
  history = model.fit(train_data,
                       validation_data=(test_data),
                       epochs=50,
                       callbacks=[checkpoint, earlystopping])
  model.load_weights(filename)
  pred = model.predict(test_data)


  return model, pred

# %%
# 모델 학습 후 변수에 저장
import numpy as np
_, pred = train_model(scaled_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# model1 training.....
# Epoch 1/50
#      59/Unknown 6s 7ms/step - loss: 0.0061 - mse: 0.0123
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 1: val_loss improved from inf to 0.00171, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.0061 - mse: 0.0121 - val_loss: 0.0017 - val_mse: 0.0034
# Epoch 2/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1996e-04 - mse: 0.0014
# Epoch 2: val_loss did not improve from 0.00171
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.4040e-04 - mse: 0.0015 - val_loss: 0.0030 - val_mse: 0.0060
# Epoch 3/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8270e-04 - mse: 0.0012
# Epoch 3: val_loss improved from 0.00171 to 0.00039, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8476e-04 - mse: 0.0012 - val_loss: 3.9485e-04 - val_mse: 7.8971e-04
# Epoch 4/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3868e-04 - mse: 6.7735e-04
# Epoch 4: val_loss did not improve from 0.00039
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.4381e-04 - mse: 6.8763e-04 - val_loss: 5.3402e-04 - val_mse: 0.0011
# Epoch 5/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5885e-04 - mse: 7.1771e-04
# Epoch 5: val_loss did not improve from 0.00039
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.6819e-04 - mse: 7.3638e-04 - val_loss: 0.0031 - val_mse: 0.0063
# Epoch 6/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5219e-04 - mse: 0.0011
# Epoch 6: val_loss improved from 0.00039 to 0.00034, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.4985e-04 - mse: 0.0011 - val_loss: 3.3916e-04 - val_mse: 6.7833e-04
# Epoch 7/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7692e-04 - mse: 5.5385e-04
# Epoch 7: val_loss did not improve from 0.00034
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.7967e-04 - mse: 5.5933e-04 - val_loss: 6.1465e-04 - val_mse: 0.0012
# Epoch 8/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6000e-04 - mse: 5.1999e-04
# Epoch 8: val_loss did not improve from 0.00034
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.6361e-04 - mse: 5.2723e-04 - val_loss: 4.6729e-04 - val_mse: 9.3458e-04
# Epoch 9/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1025e-04 - mse: 6.2050e-04
# Epoch 9: val_loss did not improve from 0.00034
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.1413e-04 - mse: 6.2827e-04 - val_loss: 3.9474e-04 - val_mse: 7.8949e-04
# Epoch 10/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4895e-04 - mse: 4.9789e-04
# Epoch 10: val_loss improved from 0.00034 to 0.00022, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.5058e-04 - mse: 5.0116e-04 - val_loss: 2.2224e-04 - val_mse: 4.4449e-04
# Epoch 11/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0753e-04 - mse: 4.1506e-04
# Epoch 11: val_loss improved from 0.00022 to 0.00020, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1188e-04 - mse: 4.2375e-04 - val_loss: 1.9734e-04 - val_mse: 3.9467e-04
# Epoch 12/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5110e-04 - mse: 5.0220e-04
# Epoch 12: val_loss did not improve from 0.00020
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.5621e-04 - mse: 5.1242e-04 - val_loss: 3.3522e-04 - val_mse: 6.7044e-04
# Epoch 13/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9444e-04 - mse: 3.8888e-04
# Epoch 13: val_loss improved from 0.00020 to 0.00019, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9750e-04 - mse: 3.9500e-04 - val_loss: 1.9263e-04 - val_mse: 3.8527e-04
# Epoch 14/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7741e-04 - mse: 3.5483e-04
# Epoch 14: val_loss improved from 0.00019 to 0.00018, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.7957e-04 - mse: 3.5914e-04 - val_loss: 1.7606e-04 - val_mse: 3.5211e-04
# Epoch 15/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6161e-04 - mse: 3.2321e-04
# Epoch 15: val_loss did not improve from 0.00018
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6691e-04 - mse: 3.3382e-04 - val_loss: 1.8019e-04 - val_mse: 3.6037e-04
# Epoch 16/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6470e-04 - mse: 3.2939e-04
# Epoch 16: val_loss did not improve from 0.00018
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6797e-04 - mse: 3.3593e-04 - val_loss: 1.7869e-04 - val_mse: 3.5738e-04
# Epoch 17/50
# 54/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6836e-04 - mse: 3.3672e-04
# Epoch 17: val_loss did not improve from 0.00018
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.7168e-04 - mse: 3.4335e-04 - val_loss: 1.8076e-04 - val_mse: 3.6153e-04
# Epoch 18/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4088e-04 - mse: 2.8176e-04
# Epoch 18: val_loss did not improve from 0.00018
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4636e-04 - mse: 2.9271e-04 - val_loss: 1.8515e-04 - val_mse: 3.7029e-04
# Epoch 19/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4198e-04 - mse: 2.8395e-04
# Epoch 19: val_loss did not improve from 0.00018
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4466e-04 - mse: 2.8932e-04 - val_loss: 2.5344e-04 - val_mse: 5.0689e-04
# Epoch 20/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3069e-04 - mse: 2.6139e-04
# Epoch 20: val_loss improved from 0.00018 to 0.00016, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3383e-04 - mse: 2.6767e-04 - val_loss: 1.6438e-04 - val_mse: 3.2876e-04
# Epoch 21/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2872e-04 - mse: 2.5744e-04
# Epoch 21: val_loss did not improve from 0.00016
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3410e-04 - mse: 2.6821e-04 - val_loss: 9.7571e-04 - val_mse: 0.0020
# Epoch 22/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4085e-04 - mse: 4.8170e-04
# Epoch 22: val_loss improved from 0.00016 to 0.00016, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4102e-04 - mse: 4.8204e-04 - val_loss: 1.5522e-04 - val_mse: 3.1044e-04
# Epoch 23/50
# 53/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5880e-04 - mse: 3.1760e-04
# Epoch 23: val_loss did not improve from 0.00016
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6646e-04 - mse: 3.3293e-04 - val_loss: 1.9831e-04 - val_mse: 3.9662e-04
# Epoch 24/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6744e-04 - mse: 3.3488e-04
# Epoch 24: val_loss did not improve from 0.00016
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6977e-04 - mse: 3.3953e-04 - val_loss: 1.7194e-04 - val_mse: 3.4387e-04
# Epoch 25/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5749e-04 - mse: 3.1498e-04
# Epoch 25: val_loss improved from 0.00016 to 0.00015, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6087e-04 - mse: 3.2175e-04 - val_loss: 1.4876e-04 - val_mse: 2.9753e-04
# Epoch 26/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4191e-04 - mse: 2.8382e-04
# Epoch 26: val_loss did not improve from 0.00015
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4367e-04 - mse: 2.8735e-04 - val_loss: 1.5873e-04 - val_mse: 3.1746e-04
# Epoch 27/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3106e-04 - mse: 2.6212e-04
# Epoch 27: val_loss did not improve from 0.00015
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3392e-04 - mse: 2.6784e-04 - val_loss: 1.8750e-04 - val_mse: 3.7501e-04
# Epoch 28/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2151e-04 - mse: 2.4302e-04
# Epoch 28: val_loss did not improve from 0.00015
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.2318e-04 - mse: 2.4637e-04 - val_loss: 2.1908e-04 - val_mse: 4.3816e-04
# Epoch 29/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2413e-04 - mse: 2.4825e-04
# Epoch 29: val_loss did not improve from 0.00015
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.2720e-04 - mse: 2.5440e-04 - val_loss: 1.9888e-04 - val_mse: 3.9776e-04
# Epoch 30/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5972e-04 - mse: 3.1945e-04
# Epoch 30: val_loss improved from 0.00015 to 0.00015, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6196e-04 - mse: 3.2392e-04 - val_loss: 1.4730e-04 - val_mse: 2.9460e-04
# Epoch 31/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0947e-04 - mse: 2.1895e-04
# Epoch 31: val_loss did not improve from 0.00015
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.1278e-04 - mse: 2.2555e-04 - val_loss: 2.6731e-04 - val_mse: 5.3461e-04
# Epoch 32/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2806e-04 - mse: 2.5612e-04
# Epoch 32: val_loss did not improve from 0.00015
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.2938e-04 - mse: 2.5875e-04 - val_loss: 5.2145e-04 - val_mse: 0.0010
# Epoch 33/50
# 53/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4118e-04 - mse: 2.8236e-04
# Epoch 33: val_loss improved from 0.00015 to 0.00014, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4708e-04 - mse: 2.9417e-04 - val_loss: 1.4002e-04 - val_mse: 2.8005e-04
# Epoch 34/50
# 53/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2020e-04 - mse: 2.4039e-04
# Epoch 34: val_loss improved from 0.00014 to 0.00014, saving model to tmp/checkpointer.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2480e-04 - mse: 2.4960e-04 - val_loss: 1.3980e-04 - val_mse: 2.7960e-04
# Epoch 35/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2502e-04 - mse: 2.5004e-04
# Epoch 35: val_loss did not improve from 0.00014
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2698e-04 - mse: 2.5397e-04 - val_loss: 3.4994e-04 - val_mse: 6.9987e-04
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8932e-04 - mse: 3.7864e-04
# Epoch 36: val_loss did not improve from 0.00014
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9056e-04 - mse: 3.8112e-04 - val_loss: 2.2547e-04 - val_mse: 4.5095e-04
# Epoch 37/50
# 54/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2988e-04 - mse: 2.5977e-04
# Epoch 37: val_loss did not improve from 0.00014
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3281e-04 - mse: 2.6562e-04 - val_loss: 2.0153e-04 - val_mse: 4.0305e-04
# Epoch 38/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2763e-04 - mse: 2.5526e-04
# Epoch 38: val_loss did not improve from 0.00014
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2848e-04 - mse: 2.5696e-04 - val_loss: 1.7646e-04 - val_mse: 3.5292e-04
# Epoch 39/50
# 54/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1225e-04 - mse: 2.2450e-04
# Epoch 39: val_loss did not improve from 0.00014
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1478e-04 - mse: 2.2956e-04 - val_loss: 1.5833e-04 - val_mse: 3.1666e-04
# Epoch 40/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1816e-04 - mse: 2.3632e-04
# Epoch 40: val_loss did not improve from 0.00014
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1938e-04 - mse: 2.3875e-04 - val_loss: 1.5307e-04 - val_mse: 3.0613e-04
# Epoch 41/50
# 54/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0127e-04 - mse: 2.0254e-04
# Epoch 41: val_loss did not improve from 0.00014
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0373e-04 - mse: 2.0747e-04 - val_loss: 2.1753e-04 - val_mse: 4.3506e-04
# Epoch 42/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0317e-04 - mse: 2.0634e-04
# Epoch 42: val_loss did not improve from 0.00014
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0412e-04 - mse: 2.0824e-04 - val_loss: 1.5170e-04 - val_mse: 3.0340e-04
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0182e-04 - mse: 2.0364e-04
# Epoch 43: val_loss did not improve from 0.00014
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0242e-04 - mse: 2.0484e-04 - val_loss: 1.5541e-04 - val_mse: 3.1082e-04
# Epoch 44/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4746e-04 - mse: 2.9492e-04
# Epoch 44: val_loss did not improve from 0.00014
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5302e-04 - mse: 3.0605e-04 - val_loss: 1.4543e-04 - val_mse: 2.9087e-04
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
# 예측데이터 시각화
plt.figure(figsize=(16, 12))
plt.plot(np.asarray(y_test)[WINDOW_SIZE:], label='actual')
plt.plot(pred, label='predict 1')
plt.legend()
plt.show()

# %%
# 성능 확인
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test[WINDOW_SIZE:], pred)
print('\n-------------------------\nMSE :', np.sqrt(mse), '\n-------------------------')
# Out:
# -------------------------
# MSE : 0.01672126559960262
# -------------------------

# %%
# 스케일링 복구
expanded_pred_values = np.zeros((pred.size, df.shape[1]))
expanded_pred_values[:, 0] = pred[:, 0]

original_scale_values = scaler.inverse_transform(expanded_pred_values)
prediction = original_scale_values[:, 0]

# prediction[-1]은 다음날 예측 가격
print('Model 1 - 8월 29일 종가: ',prediction[-1])
print(df.columns)
# Out:
# Model 1 - 8월 29일 종가:  71278.67395877838
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Volatility', '기관 순매매량',
#        '외국인 순매매량', '외국인 보유주수', '외국인 보유율', 'neutral', 'positive', 'negative'],
#       dtype='object')
